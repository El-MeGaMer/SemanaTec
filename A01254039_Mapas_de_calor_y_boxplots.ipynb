# %% [markdown]
# <a href="https://colab.research.google.com/github/El-MeGaMer/SemanaTec/blob/Obtenci%C3%B3n-de-estadisticas-descriptivas/A01254039_Mapas_de_calor_y_boxplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cargar Datos

# %%
import pandas as pd
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-bdd2cd45-7cf2-4ae2-98d2-b59e3eb57f9c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdd2cd45-7cf2-4ae2-98d2-b59e3eb57f9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('credit.csv')
df.head(2)
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903

# %%
df.shape
# Out:
# (400, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  400 non-null    int64
#  1   Income      400 non-null    float64
#  2   Limit       400 non-null    int64
#  3   Rating      400 non-null    int64
#  4   Cards       400 non-null    int64
#  5   Age         400 non-null    int64
#  6   Education   400 non-null    int64
#  7   Gender      400 non-null    object
#  8   Student     400 non-null    object
#  9   Married     400 non-null    object
#  10  Ethnicity   400 non-null    object
#  11  Balance     400 non-null    int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 37.6+ KB

# %%
df1=df.drop(['Unnamed: 0'], axis=1)

# %%
df1.describe()
# Out:
#            Income         Limit      Rating       Cards         Age  \
# count  400.000000    400.000000  400.000000  400.000000  400.000000
# mean    45.218885   4735.600000  354.940000    2.957500   55.667500
# std     35.244273   2308.198848  154.724143    1.371275   17.249807
# min     10.354000    855.000000   93.000000    1.000000   23.000000
# 25%     21.007250   3088.000000  247.250000    2.000000   41.750000
# 50%     33.115500   4622.500000  344.000000    3.000000   56.000000
# 75%     57.470750   5872.750000  437.250000    4.000000   70.000000
# max    186.634000  13913.000000  982.000000    9.000000   98.000000
#
#         Education      Balance
# count  400.000000   400.000000
# mean    13.450000   520.015000
# std      3.125207   459.758877
# min      5.000000     0.000000
# 25%     11.000000    68.750000
# 50%     14.000000   459.500000
# 75%     16.000000   863.000000
# max     20.000000  1999.000000

# %% [markdown]
# Histogramas

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Income', hue='Gender', bins=20, kde=True)

plt.xlabel('Longitud del ingreso')
plt.ylabel('Frecuencia en generos')
plt.title('Comparación de la distribución del ingreso por genero')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del ingreso por genero')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Income', hue='Student', bins=20, kde=True)

plt.xlabel('Longitud del ingreso')
plt.ylabel('Frecuencia de estudiantes')
plt.title('Comparación de la distribución del ingreso por estudiante')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del ingreso por estudiante')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Income', hue='Married', bins=20, kde=True)

plt.xlabel('Longitud del ingreso')
plt.ylabel('Frecuencia de Casados')
plt.title('Comparación de la distribución del ingreso por casados')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del ingreso por casados')

# %% [markdown]
# 4. Basándose en la media, mediana y desviación estándar de cada variable, que conclusiones puedes entregar de los datos.

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Income', hue='Ethnicity', bins=20, kde=True)

plt.xlabel('Longitud del ingreso')
plt.ylabel('Frecuencia en etnia')
plt.title('Comparación de la distribución del ingreso por etnia')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del ingreso por etnia')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Limit', hue='Gender', bins=20, kde=True)

plt.xlabel('Longitud del limite')
plt.ylabel('Frecuencia en generos')
plt.title('Comparación de la distribución del limite por genero')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del limite por genero')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Limit', hue='Student', bins=20, kde=True)

plt.xlabel('Longitud del limite')
plt.ylabel('Frecuencia de estudiantes')
plt.title('Comparación de la distribución del limite por estudiante')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del limite por estudiante')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Limit', hue='Married', bins=20, kde=True)

plt.xlabel('Longitud del limite')
plt.ylabel('Frecuencia de Casados')
plt.title('Comparación de la distribución del limite por casados')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del limite por casados')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Limit', hue='Ethnicity', bins=20, kde=True)

plt.xlabel('Longitud del limite')
plt.ylabel('Frecuencia en etnia')
plt.title('Comparación de la distribución del limite por etnia')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del limite por etnia')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Cards', hue='Gender', bins=20, kde=True)

plt.xlabel('Longitud del cartas')
plt.ylabel('Frecuencia en generos')
plt.title('Comparación de la distribución del cartas por genero')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del cartas por genero')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Cards', hue='Student', bins=20, kde=True)

plt.xlabel('Longitud del cartas')
plt.ylabel('Frecuencia de estudiantes')
plt.title('Comparación de la distribución del cartas por estudiante')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del cartas por estudiante')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Cards', hue='Married', bins=20, kde=True)

plt.xlabel('Longitud del cartas')
plt.ylabel('Frecuencia de Casados')
plt.title('Comparación de la distribución del cartas por casados')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del cartas por casados')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Cards', hue='Ethnicity', bins=20, kde=True)

plt.xlabel('Longitud del cartas')
plt.ylabel('Frecuencia en etnia')
plt.title('Comparación de la distribución de cartas por etnia')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución de cartas por etnia')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Rating', hue='Gender', bins=20, kde=True)

plt.xlabel('Longitud del rating')
plt.ylabel('Frecuencia en generos')
plt.title('Comparación de la distribución del rating por genero')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del rating por genero')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Rating', hue='Student', bins=20, kde=True)

plt.xlabel('Longitud del rating')
plt.ylabel('Frecuencia de estudiantes')
plt.title('Comparación de la distribución del rating por estudiante')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del rating por estudiante')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Rating', hue='Married', bins=20, kde=True)

plt.xlabel('Longitud del rating')
plt.ylabel('Frecuencia de Casados')
plt.title('Comparación de la distribución del rating por casados')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución del rating por casados')

# %%
fig = plt.figure(figsize=(9,6))

sns.histplot(data=df1, x='Rating', hue='Ethnicity', bins=20, kde=True)

plt.xlabel('Longitud del rating')
plt.ylabel('Frecuencia en etnia')
plt.title('Comparación de la distribución de rating por etnia')
# Out:
# Text(0.5, 1.0, 'Comparación de la distribución de rating por etnia')

# %% [markdown]
# Graficas de Dispersion

# %%
fig = plt.figure(figsize=(6,4))

sns.pairplot(data=df1, hue='Income')

plt.grid(True)

# %% [markdown]
# Mapas de Calor

# %%
credit_corr = df1.corr()

sns.heatmap(data=credit_corr)
# Out:
# <Axes: >

# %%
sns.heatmap(data=credit_corr, vmin=-1, vmax=1, cmap = 'RdBu', annot=True, square = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Diagramas de bigote

# %% [markdown]
# Genero

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Income', y = 'Gender')

plt.title('Histograma del ancho del ingreso por genero')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del ingreso por genero')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Limit', y = 'Gender')

plt.title('Histograma del ancho del limite por genero')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del limite por genero')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Cards', y = 'Gender')

plt.title('Histograma del ancho de las cartas por genero')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho de las cartas por genero')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Balance', y = 'Gender')

plt.title('Histograma del ancho del balance por genero')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del balance por genero')

# %% [markdown]
# Estudiantes

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Income', y = 'Student')

plt.title('Histograma del ancho del ingreso por estudiante')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del ingreso por estudiante')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Limit', y = 'Student')

plt.title('Histograma del ancho del limite por estudiante')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del limite por estudiante')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Cards', y = 'Student')

plt.title('Histograma del ancho de las cartas por estudiante')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho de las cartas por estudiante')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Balance', y = 'Student')

plt.title('Histograma del ancho del balance por estudiante')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del balance por estudiante')

# %% [markdown]
# Casados

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Income', y = 'Married')

plt.title('Histograma del ancho del ingreso por casados')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del ingreso por casados')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Limit', y = 'Married')

plt.title('Histograma del ancho del limite por casados')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del limite por casados')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Cards', y = 'Married')

plt.title('Histograma del ancho de las cartas por casados')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho de las cartas por casados')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Balance', y = 'Married')

plt.title('Histograma del ancho del balance por casados')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del balance por casados')

# %% [markdown]
# Etnia

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Income', y = 'Ethnicity')

plt.title('Histograma del ancho del ingreso por etnia')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del ingreso por etnia')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Limit', y = 'Ethnicity')

plt.title('Histograma del ancho del limite por etnia')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del limite por etnia')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Cards', y = 'Ethnicity')

plt.title('Histograma del ancho de las cartas  por etnia')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho de las cartas  por etnia')

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df1, x='Balance', y = 'Ethnicity')

plt.title('Histograma del ancho del balance por etnia')
# Out:
# Text(0.5, 1.0, 'Histograma del ancho del balance por etnia')
